# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("C:\\Users\\pawan\\Downloads\\kidney_disease.csv", header=0, na_values="?")

# %%
dataset.replace("?", np.NaN)
dataset.head(1)
# Out:
#    id   age    bp    sg   al   su  rbc      pc         pcc          ba  ...  \
# 0   0  48.0  80.0  1.02  1.0  0.0  NaN  normal  notpresent  notpresent  ...
#
#    pcv    wc   rc  htn   dm  cad appet  pe ane classification
# 0   44  7800  5.2  yes  yes   no  good  no  no            ckd
#
# [1 rows x 26 columns]

# %%
cleanup = {"Rbc":     {"normal": 1, "abnormal": 0},
           "Pc": {"normal": 1, "abnormal": 0},
           "Pcc": {"present": 1, "notpresent": 0},
           "Ba": {"present": 1, "notpresent": 0},
           "Htn": {"yes": 1, "no": 0},
           "Dm": {"yes": 1, "no": 0},
           "Cad": {"yes": 1, "no": 0},
           "Appet": {"good": 1, "poor": 0},
           "pe": {"yes": 1, "no": 0},
           "Ane": {"yes": 1, "no": 0}}

# %%
dataset.replace(cleanup, inplace=True)

# %%
dataset.fillna(round(dataset.mean(),2), inplace=True)

# %%
print(dataset)
# Out:
#       id   age      bp     sg    al    su       rbc        pc         pcc  \
# 0      0  48.0   80.00  1.020  1.00  0.00       NaN    normal  notpresent
# 1      1   7.0   50.00  1.020  4.00  0.00       NaN    normal  notpresent
# 2      2  62.0   80.00  1.010  2.00  3.00    normal    normal  notpresent
# 3      3  48.0   70.00  1.005  4.00  0.00    normal  abnormal     present
# 4      4  51.0   80.00  1.010  2.00  0.00    normal    normal  notpresent
# 5      5  60.0   90.00  1.015  3.00  0.00       NaN       NaN  notpresent
# 6      6  68.0   70.00  1.010  0.00  0.00       NaN    normal  notpresent
# 7      7  24.0   76.47  1.015  2.00  4.00    normal  abnormal  notpresent
# 8      8  52.0  100.00  1.015  3.00  0.00    normal  abnormal     present
# 9      9  53.0   90.00  1.020  2.00  0.00  abnormal  abnormal     present
# 10    10  50.0   60.00  1.010  2.00  4.00       NaN  abnormal     present
# 11    11  63.0   70.00  1.010  3.00  0.00  abnormal  abnormal     present
# ...

# %%
dataset.to_csv("C:\\Users\\pawan\\Downloads\\preprocessed.csv", sep=',', index=False)
